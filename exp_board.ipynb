# %%
import pandas as pd
import numpy as np
# 读取数据
dir_path = 'C:/Users/Yuetong/DataSet/tcjr/'
operation_train_path = dir_path + 'operation_train_new.csv'
transaction_train_path = dir_path + 'transaction_train_new.csv'
tag_train_path = dir_path + 'tag_train_new.csv'
operation_df = pd.read_csv(operation_train_path)
transaction_df = pd.read_csv(transaction_train_path)
tag_df = pd.read_csv(tag_train_path)

# %%
# 根据UID分组
operation_grouped = operation_df.groupby('UID')
id2operation={}
for name,group in operation_grouped:
    id2operation[name] = group

transaction_grouped = transaction_df.groupby('UID')
id2transaction={}
for name,group in transaction_grouped:
    id2transaction[name] = group

# %%
# 标签数据
id2tag=dict(tag_df.values.tolist())

# %%
id2operation[10000]
# Out:
#           UID  day              mode  success      time   os version  \
# 87507   10000   13  c8741ce15ceac2a4      1.0  14:20:56  103   7.0.5
# 96940   10000   26  c8741ce15ceac2a4      1.0  12:23:48  103   7.0.7
# 150480  10000   26  d25caee90b27fa9b      1.0  12:24:21  103   7.0.7
# 168206  10000   26  c8741ce15ceac2a4      1.0  12:23:48  103   7.0.7
# 196361  10000   26  c8741ce15ceac2a4      1.0  12:23:48  103   7.0.7
# 216744  10000   13  270ca3ca8f0d1126      1.0  14:22:59  103   7.0.5
# 307385  10000   13  c8741ce15ceac2a4      1.0  14:20:56  103   7.0.5
# 339411  10000   26  d25caee90b27fa9b      1.0  12:24:01  103   7.0.7
# 420183  10000   13  c8741ce15ceac2a4      1.0  14:20:56  103   7.0.5
#
#                  device1   device2 device_code1 device_code2  \
# 87507   aca4977fbe8741e1  IPHONE 5          NaN          NaN
# 96940   aca4977fbe8741e1  IPHONE 5          NaN          NaN
# 150480  aca4977fbe8741e1       NaN          NaN          NaN
# 168206  aca4977fbe8741e1  IPHONE 5          NaN          NaN
# 196361  aca4977fbe8741e1  IPHONE 5          NaN          NaN
# 216744  aca4977fbe8741e1  IPHONE 5          NaN          NaN
# 307385  aca4977fbe8741e1  IPHONE 5          NaN          NaN
# 339411  aca4977fbe8741e1       NaN          NaN          NaN
# 420183  aca4977fbe8741e1  IPHONE 5          NaN          NaN
#
#             device_code3 mac1 mac2               ip1  ip2 wifi geo_code  \
# 87507   deb68f7028682008  NaN  NaN  31599eec867ba9c7  NaN  NaN      NaN
# 96940   deb68f7028682008  NaN  NaN  34c715882de1a508  NaN  NaN      NaN
# 150480  deb68f7028682008  NaN  NaN  34c715882de1a508  NaN  NaN      NaN
# 168206  deb68f7028682008  NaN  NaN  34c715882de1a508  NaN  NaN      NaN
# 196361  deb68f7028682008  NaN  NaN  34c715882de1a508  NaN  NaN      NaN
# 216744  deb68f7028682008  NaN  NaN  31599eec867ba9c7  NaN  NaN      NaN
# 307385  deb68f7028682008  NaN  NaN  31599eec867ba9c7  NaN  NaN      NaN
# 339411  deb68f7028682008  NaN  NaN  34c715882de1a508  NaN  NaN      NaN
# 420183  deb68f7028682008  NaN  NaN  31599eec867ba9c7  NaN  NaN      NaN
#
#                  ip1_sub ip2_sub
# 87507   ee08d48e73120da4     NaN
# 96940   1e3ea9498c461cbf     NaN
# 150480  1e3ea9498c461cbf     NaN
# 168206  1e3ea9498c461cbf     NaN
# 196361  1e3ea9498c461cbf     NaN
# 216744  ee08d48e73120da4     NaN
# 307385  ee08d48e73120da4     NaN
# 339411  1e3ea9498c461cbf     NaN
# 420183  ee08d48e73120da4     NaN

# %%
id2transaction[10000]
# Out:
#           UID  channel  day      time  trans_amt          amt_src1  \
# 90698   10000      140   26  12:23:56       5536  f29829bc82459191
# 134052  10000      140   26  12:24:17       5536  f29829bc82459191
#
#                 merchant code1 code2       trans_type1        ...         \
# 90698   88aa547576f43f85   NaN   NaN  c2f2023d279665b2        ...
# 134052  88aa547576f43f85   NaN   NaN  c2f2023d279665b2        ...
#
#                      ip1  bal          amt_src2 acc_id2 acc_id3 geo_code  \
# 90698   34c715882de1a508  100  9a8ee16bde15e38a     NaN     NaN      NaN
# 134052  34c715882de1a508  100  9a8ee16bde15e38a     NaN     NaN      NaN
#
#        trans_type2 market_code  market_type           ip1_sub
# 90698        105.0         NaN          NaN  1e3ea9498c461cbf
# 134052       105.0         NaN          NaN  1e3ea9498c461cbf
#
# [2 rows x 27 columns]

# %%
group_o=id_2_operation[10000]
group_t=id_2_transaction[10000]
group_t.shape[0]
# Out:
# 2

# %%
# amount of operation
def amount_of_operation(group):
    return group.shape[0]
def amount_of_transaction(group):
    return group.shape[0]
